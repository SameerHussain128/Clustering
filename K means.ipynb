# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_blobs

# %%
X,y=make_blobs(n_samples=1000,centers=3,n_features=2,random_state=23)

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.scatter(X[:,0],X[:,1])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(
X,y,test_size=0.33,random_state=42)

# %%
from sklearn.cluster import KMeans

# %%
# Manual process
# Elbow method to select the K value

wcss=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k,init='k-means++')
    kmeans.fit(X_train)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\SAMEER\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
wcss
# Out:
# [34827.57682552022,
#  7935.437286145416,
#  1319.2730531585607,
#  1140.4677884655127,
#  993.2610874458237,
#  853.8119934676828,
#  754.4209992047872,
#  665.3644109371673,
#  578.1189222815924,
#  531.4220481870643]

# %%
# plot elbow graph
plt.plot(range(1,11),wcss)
plt.xtricks(range(1,11))
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21448\3502787703.py in <module>
#       1 # plot elbow graph
#       2 plt.plot(range(1,11),wcss)
# ----> 3 plt.xtricks(range(1,11))
#       4 plt.xlabel("Number of Clusters")
#       5 plt.ylabel("WCSS")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xtricks'

# %%
kmeans=KMeans(n_clusters=3,init="k-means++")

# %%
y_labels=kmeans.fit_predict(X_train)

# %%
y_test_label=kmeans.predict(X_test)

# %%
plt.scatter(X_train[:,0],X_train[:,1],c=y_labels)

# %%
plt.scatter(X_test[:,0],X_test[:,1],c=y_test_label)

# %%
# knee locator
# !pip install kneed
# Out:
# Collecting kneed
#   Downloading kneed-0.8.5-py3-none-any.whl (10 kB)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\sameer\anaconda3\lib\site-packages (from kneed) (1.9.1)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\sameer\anaconda3\lib\site-packages (from kneed) (1.21.5)
# Installing collected packages: kneed
# Successfully installed kneed-0.8.5
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\sameer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\sameer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\sameer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\sameer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\sameer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\sameer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\sameer\anaconda3\lib\site-packages)

# %%
from kneed import KneeLocator

# %%
# if wcss increase we use concave, if decrease use convex
kl=KneeLocator(range(1,11),wcss,curve='convex',direction='decreasing')

# %%
kl.elbow
# Out:
# 3

# %%
# Performance metrics
# Silhoutte score
from sklearn.metrics import silhouette_score

# %%
silhouette_coefficients=[]
for k in range(2,11):
    kmeans=KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(X_train)
    score=silhouette_score(X_train,kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
silhouette_coefficients
# Out:
# [0.7281443868598331,
#  0.8071181203797672,
#  0.6357733426488265,
#  0.4907093255057165,
#  0.33691828928108875,
#  0.3413143281324173,
#  0.34920504145170617,
#  0.3440227738230679,
#  0.3441220898278038]

# %%
# plot elbow graph
plt.plot(range(2,11),silhouette_coefficients)
plt.xtricks(range(2,11))
plt.xlabel("Number of Clusters")
plt.ylabel("silhouette_coefficients")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21448\823397036.py in <module>
#       1 # plot elbow graph
#       2 plt.plot(range(2,11),silhouette_coefficients)
# ----> 3 plt.xtricks(range(2,11))
#       4 plt.xlabel("Number of Clusters")
#       5 plt.ylabel("silhouette_coefficients")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xtricks'
